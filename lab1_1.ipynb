# %%
from lab1_functions import *
from lab1_classes import *
maze = generate_maze()
time_horizon = 20
entry = (0, 0)
exit = (6, 5)
states = StateSpace(maze=maze,
                    time_horizon=time_horizon,
                    entry=entry, exit=exit,
                    minotaur_can_stand_still=True)
rewards = Reward(reward_eaten=-1, reward_exiting=1)
backward_induction(states=states, rewards=rewards)
# Out:
# States generated.
# Backwards induction at t = 19
# Backwards induction at t = 18
# Backwards induction at t = 17
# Backwards induction at t = 16
# Backwards induction at t = 15
# Backwards induction at t = 14
# Backwards induction at t = 13
# Backwards induction at t = 12
# Backwards induction at t = 11
# Backwards induction at t = 10
# Backwards induction at t = 9
# Backwards induction at t = 8
# Backwards induction at t = 7
# Backwards induction at t = 6
# Backwards induction at t = 5
# Backwards induction at t = 4
# Backwards induction at t = 3
# Backwards induction at t = 2
# Backwards induction at t = 1
# Backwards induction at t = 0

# %%
run_game(maze=maze, states=states, rewards=rewards)
# Out:
# At time 0
# player @ (0, 0)
# minotaur @ (6, 5)
# At time 1
# player @ (0, 1)
# minotaur @ (5, 5)
# At time 2
# player @ (1, 1)
# minotaur @ (4, 5)
# At time 3
# player @ (2, 1)
# minotaur @ (4, 5)
# At time 4
# player @ (3, 1)
# minotaur @ (4, 5)
# At time 5
# player @ (4, 1)
# minotaur @ (4, 5)
# At time 6
# player @ (4, 2)
# minotaur @ (3, 5)
# At time 7
# player @ (4, 3)
# minotaur @ (3, 6)
# At time 8
# player @ (4, 4)
# minotaur @ (3, 5)
# At time 9
# player @ (4, 4)
# minotaur @ (3, 4)
# At time 10
# player @ (4, 5)
# minotaur @ (3, 5)
# At time 11
# player @ (4, 6)
# minotaur @ (3, 5)
# At time 12
# player @ (4, 7)
# minotaur @ (3, 5)
# At time 13
# player @ (5, 7)
# minotaur @ (3, 6)
# At time 14
# player @ (6, 7)
# minotaur @ (2, 6)
# At time 15
# player @ (6, 6)
# minotaur @ (2, 6)
# At time 16
# player @ (6, 5)
# minotaur @ (2, 7)
# At time 17
# player @ (6, 5)
# minotaur @ (2, 7)
# At time 18
# player @ (6, 5)
# minotaur @ (2, 7)
# At time 19
# player @ (6, 5)
# minotaur @ (2, 7)
